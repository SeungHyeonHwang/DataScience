# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
s = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2020', periods=1000))
s
s.plot()

# %%
s = s.cumsum() # 누적합
s.plot()

# %%
r = s.rolling(window=30)
r.mean()
# Out:
# 2020-01-01          NaN
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-04          NaN
# 2020-01-05          NaN
#                 ...
# 2022-09-22   -28.219757
# 2022-09-23   -28.252930
# 2022-09-24   -28.283245
# 2022-09-25   -28.298666
# 2022-09-26   -28.354050
# Freq: D, Length: 1000, dtype: float64

# %%
# 롱링은 이동평균 
s.plot(style='k--') # 추세선
r.mean().plot(style='r')

# %%
df = pd.DataFrame(np.random.randn(1000,4), 
                  index = pd.date_range('1/1/2000', periods=1000),
                  columns=['A','B','C','D'])
df
# Out:
#                    A         B         C         D
# 2000-01-01 -0.405357  1.321891  0.027658  0.091795
# 2000-01-02  1.053584 -1.200569 -1.492549  0.668657
# 2000-01-03  1.643274 -0.763335  0.720331  0.913417
# 2000-01-04  0.460332  0.613669  2.756529 -0.740756
# 2000-01-05 -1.267214 -0.311524  1.177460 -0.203188
# ...              ...       ...       ...       ...
# 2002-09-22 -0.061540  0.230833  1.846424  1.218200
# 2002-09-23 -0.069690 -2.383989 -0.090725  0.777397
# 2002-09-24  0.258228  0.183588 -0.311652 -2.031828
# 2002-09-25 -1.129805  0.775499  1.389363 -0.765285
# 2002-09-26 -1.216831 -1.705534 -0.114701  0.020451
#
# [1000 rows x 4 columns]

# %%
df = df.cumsum()
df
# Out:
#                     A          B          C          D
# 2000-01-01  -0.405357   1.321891   0.027658   0.091795
# 2000-01-02   0.648227   0.121322  -1.464891   0.760452
# 2000-01-03   2.291501  -0.642013  -0.744560   1.673869
# 2000-01-04   2.751833  -0.028344   2.011969   0.933113
# 2000-01-05   1.484619  -0.339868   3.189429   0.729925
# ...               ...        ...        ...        ...
# 2002-09-22 -38.865152 -13.141879  13.457968 -10.000780
# 2002-09-23 -38.934842 -15.525868  13.367243  -9.223383
# 2002-09-24 -38.676614 -15.342280  13.055591 -11.255211
# 2002-09-25 -39.806419 -14.566781  14.444954 -12.020496
# 2002-09-26 -41.023250 -16.272315  14.330254 -12.000045
#
# [1000 rows x 4 columns]

# %%
df.plot()

# %%
df.rolling(window=60).sum().plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002E4252F1898>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002E425348E48>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002E4253862E8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002E4253B8748>],
#       dtype=object)

# %%
df.rolling(window=len(df), min_periods=1).mean().plot()

# %%
df.expanding(min_periods=1).mean().plot()

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2020', periods=1000))
ts
# Out:
# 2020-01-01   -0.594130
# 2020-01-02   -1.097472
# 2020-01-03    1.879064
# 2020-01-04    1.603753
# 2020-01-05   -0.266641
#                 ...
# 2022-09-22    0.770043
# 2022-09-23    0.798172
# 2022-09-24   -0.231342
# 2022-09-25   -0.902944
# 2022-09-26    0.690293
# Freq: D, Length: 1000, dtype: float64

# %%
df = pd.DataFrame(np.random.randn(1000,4), 
                  index = ts.index,
                  columns=list('ABCD'))
df.head(6)
# Out:
#                    A         B         C         D
# 2020-01-01 -0.254601 -0.738725  2.850253  2.438909
# 2020-01-02  0.341494 -0.294618  1.171385  0.109284
# 2020-01-03  1.823309 -0.172641 -0.476739  0.392172
# 2020-01-04 -0.243675 -0.270223 -0.285141 -0.866033
# 2020-01-05  0.368320  0.102726  2.189361  1.353290
# 2020-01-06 -0.455095 -0.542213  0.271063  0.520164

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2022-09-25  0.057939  0.442186 -1.129076 -1.149938
# 2022-09-26 -0.676558  0.565836 -1.107690 -0.904955

# %%
df.iloc[5].plot(kind='bar') # iloc = index 5 = 5행(2020-01-06) / 0행부터 시작

# %%
df.iloc[5].plot.bar()
plt.axhline(0.5,color='k')

# %%
df.iloc[5].plot.box()

# %%
df2 = pd.DataFrame(np.random.rand(10,4), columns=list('ABCD'))

df2.head()
# Out:
#           A         B         C         D
# 0  0.772417  0.414485  0.393786  0.804172
# 1  0.978078  0.113791  0.148774  0.866074
# 2  0.999167  0.214930  0.335639  0.777753
# 3  0.979769  0.587900  0.870857  0.292942
# 4  0.762997  0.059727  0.651243  0.247348

# %%
df2.plot.bar(stacked=True)

# %%
df2.plot.barh(stacked=True)
